# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import os

# %%
NPFiles = []
NPDataTablesNames = []
mydir = 'K:\CPDiary\Data\BaxtersMVI\TestData'
for file in os.listdir(mydir):
    if file.endswith('.NP1'):
        NPFiles.append(os.path.join(mydir, file))
        NPDataTablesNames.append(os.path.splitext(file)[0])
    if file.endswith('.NP2'):
        NPFiles.append(os.path.join(mydir, file))
        NPDataTablesNames.append(os.path.splitext(file)[0])

# %%
NPFiles
# Out:
# ['D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091023.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091106.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091110.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091116.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091120.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091124.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091127.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc091204.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\MC091212.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\MC091218.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\MC091228.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc100106.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\MC100118.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc100202.np',
#  'D:\\GitHubRepos\\MVI\\RA1.3\\TestData\\mc100223.np']

# %%
NPDataTablesNames
# Out:
# ['mc091023',
#  'mc091106',
#  'mc091110',
#  'mc091116',
#  'mc091120',
#  'mc091124',
#  'mc091127',
#  'mc091204',
#  'MC091212',
#  'MC091218',
#  'MC091228',
#  'mc100106',
#  'MC100118',
#  'mc100202',
#  'mc100223']

# %%
ColumnsHeaders = ['Number','NotSure','WhoKnows','WhatThe','Year','Month','Day','Plot','M7','M6','M5','M4','M3','M2','M1']

# %%
len(ColumnsHeaders)
# Out:
# 15

# %%
test = pd.DataFrame(columns = ColumnsHeaders, data=pd.read_csv(file,skiprows = range(18),
                             header=None).values)
#test.columns = ColumnsHeaders

# %%
test
# Out:
#     Number  NotSure  WhoKnows  WhatThe  Year  Month   Day  Plot    M7    M6  \
# 0    585.0      1.1       3.0      9.0   9.0   16.0  10.0   6.0  35.7  33.4
# 1    584.0      3.1       3.0      9.0   9.0   16.0  10.0  13.0  34.1  33.8
# 2    583.0      3.2       3.0      9.0   9.0   16.0  10.0  10.0  30.8  33.3
# 3    582.0      4.1       3.0      9.0   9.0   16.0  10.0  25.0  32.1  31.1
# 4    581.0      4.2       3.0      9.0   9.0   16.0  10.0  30.0  31.8  36.1
# 5    580.0      5.2       3.0      9.0   9.0   16.0  10.0  36.0  31.8  32.0
# 6    579.0      7.2       3.0      9.0   9.0   16.0  14.0   4.0  31.0  32.1
# 7    578.0      8.1       3.0      9.0   9.0   16.0  14.0   1.0  34.2  31.2
# 8    577.0      8.2       3.0      9.0   9.0   16.0  14.0  14.0  32.5  28.4
# 9    576.0     10.1       3.0      9.0   9.0   16.0  14.0  21.0  31.1  32.6
# 10   575.0     10.2       3.0      9.0   9.0   16.0  14.0  27.0  32.2  33.5
# ...

# %%
NPData = pd.DataFrame(columns=ColumnsHeaders)
for filename in NPFiles:
    DataFrame = pd.DataFrame(columns = ColumnsHeaders, 
                             data=pd.read_csv(file,skiprows = range(18),header=None).values)
    NPData.append(DataFrame)

# %%
NPData
# Out:
# Empty DataFrame
# Columns: [Number, NotSure, WhoKnows, WhatThe, Year, Month, Day, Plot, M7, M6, M5, M4, M3, M2, M1]
# Index: []
